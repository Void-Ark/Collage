# %% [markdown]
# ## INTRODUCTION
#
# There are two brought applications for working on the data science
# 1. licenced app.
#     - power bi, tabal, IBS HTS, AMOS (ana. of moment of strut.), lisre, statistic, SAS
#     - these are basically use for data visualization
#     -  to run these app. we need an individial llisence or a instutuional lisence
#     - all these app. are GUI based and coding free
# 2. open-source
#     - the two most popular open source languages in the field of DS are R and python.4
#     - to use these languages some kind of coding is req. but it is possible to do anything in an opensource language like R and Python.
# ---
#
# There are basically three part in the Data Scienve or Data Analytics
# 1. Writing the code in r/python
# 2. Trying to find out what kind of stastistics has to be used
# 3. Python code will give you some kind of the output trying to understand the interpretation of the output.
# ---
#
# #### Applications of Data Science
#
# **Booking the cab with OLA app**
# - there are four clustor of vehicle : micro , mini, prime and sidhan
# - try to identify how a new model of a car manufacturor will be assigned to each of these four clustors.
# - this is known as segmental Analysis
#
# **Predictive Analysis**
# - In the segmental analysis there should be homoginity and the cluster itself should be hetrogeneous in nature while in predictive analysis we are interested to do some kind of the prediction
# - Example :
#     - Predicting how many runs india will score
#     - predicting whether india will win or loose the match
#     - Whether a person is eligible for a lone
#     - Eligibility of the customer for the credit card
#     - Whether a student will pass/fail in the exam
#
# **Associative modul**
# - how to build a associative model which can find out the group of products generally perchased by the customer.
#
# **Statistical Analysis** is the process of analysing and conncting sample of data to uncover the pattern so that the decisions are more scientific more accurate. The raw material for data analytics is the data.
#
# ---
#
# **There are two sources to get data**
# 1. is the primary sources
#     - google form is the most widly used primary use for collecting the data
# 2. Secondary Source :
#     - there is lot of data we get from internet/
#     - Kaggle, github are the two most popular secondary source for downloading the data from the net.
#
# ---
#
#
# **the popular formats are :**
# - .csv -> created on notepad
# - - for importing csv file the fun.: pd.read_csv() -> python fun.
# - 'excel' file -> a csv file in excel has only one spreadsheet while excel file can store more
# - - to import a .csv file we don't need to specify the name of the worksheet while in excel needed to specify the worksheet to import
# - .mdv -> from microsoft access
# - .xav -> from IBM hpss (lisenced)
# - .sql ->
# - .sas ->
#
# to import files of different format into jupyter notebook different functions will be req.
#
# ---
#
#
# **What is the Library in the Python?**
#
# Popular lib. :
# - numpy (numerical python) : This library is used to handle matrix(2-dim.), array(n-dim), vectors(one dim.).
# - scipy (scientific python): This lib. is used for all the scientific functions like eigen value and vector, test of normality and outlier and presence of missing value
# - matplotlib, seaborn : these lib. are used for making graphics in py. like pychart, bar plot, scatter plot, etc.
# - statsmodels : this lib. is used for statistical functions like linear regression.
# - scitlearn : This lib. is used to create all the ML models in py.
